# %% [markdown]
# # Example usage of difference_estimation_plot.py
# ## for mean/median comparison between groups

# %%
import numpy as np
import difference_estimation_plot as dpl

# %%
## Unpaired example:
input_ = {'sample 1': np.random.rand(100)+1, 'sample 2': np.random.rand(90) + 0.9,
     'sample 3': np.random.rand(200) +2}
KEYS = list(input_.keys())
fig,axs = dpl.estimation_plot(input_, [KEYS], SMOOTH=[1,3])

# %%
## Paired example:
input_ = {'sample 1': np.random.rand(10), 'sample 2': np.random.rand(10) + 0.4,
     'sample 3': np.random.rand(10) - 0.2}
KEYS = list(input_.keys())
fig,axs = dpl.estimation_plot(input_, [KEYS], trend=2, SMOOTH=[1,3])

# %%
## Median difference example:
input_ = {'sample 1': np.random.rand(100), 'sample 2': np.random.rand(100) + 0.4,
     'sample 3': np.random.rand(200) - 0.2}
KEYS = list(input_.keys())
fig,axs = dpl.estimation_plot(input_, [KEYS], trend=1, operation=np.median)

# %%
## Multiple controls
input_ = {'sample 1': np.random.rand(100), 'sample 2': np.random.rand(100) + 0.4,
         'sample 3': np.random.rand(100) - 0.2, 'sample 4': np.random.rand(100) - 0.1}
KEYS = list(input_.keys())
fig,axs = dpl.estimation_plot(input_, [KEYS[:2], KEYS[2:]], trend=1,\
                          vertical=1, nsh=2000)
