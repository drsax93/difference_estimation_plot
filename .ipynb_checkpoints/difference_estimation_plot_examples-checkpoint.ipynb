# %% [markdown]
# ### Example usage of difference_estimation_plot.py
# ### for mean/median comparison between groups

# %%
import importlib
import numpy as np
import difference_estimation_plot as dpl

# %%
importlib.reload(dpl)
# Out:
# <module 'difference_estimation_plot' from '/Users/GiuseppePietro/Python/difference_estimation_plot/difference_estimation_plot.py'>

# %%
## Unpaired example:
a = .2
input_ = {'sample 1': a*np.random.normal(size=(2000)), 'sample 2': a*np.random.normal(size=(1000)) + 0.01,
     'sample 3': a*np.random.normal(size=(1000)) +0.1, 'sample 4': a*np.random.normal(size=(1500)) +.2}
KEYS = list(input_.keys());

axs = dpl.nested_subplots()
ax, m, p = dpl.estimation_plot(input_, [KEYS[:2],KEYS[2:]], operation=np.mean, nsh=5000,
                                 ci=[0,.95], color_palette=['r', 'g', 'b', 'y'], paired=False,
                                 axs=axs[0], vertical=1, figsize=(6,4), trend=0, spread=3,
                              bootPlot_kw={'ci_size':6,'ci_width':2,'ref_width':2},
                              swarmPlot_kw={'s':1,'m':'o', 'mfc':['none',1,1,'none'],
                                            'es_width':2})

ax, m, p = dpl.estimation_plot(input_, [KEYS[:2],KEYS[2:]], operation=np.mean, nsh=5000,ci=.95,
                              color_palette=['r', 'g', 'b', 'y'], paired=False, axs=axs[1],
                              vertical=1, figsize=(6,4), trend=0, spread=3,
                              bootPlot_kw={'ci_size':6,'ci_width':2,'ref_width':2},
                              swarmPlot_kw={'s':1,'m':'o', 'mfc':['none',1,1,'none'],
                                            'es_width':2})
print(f'The standard bootstrap estimation p-values are: {p[0][0][0]} and {p[1][0][0]}')
print(f'The bca bootstrap estimation p-values are: {p[0][0][1]} and {p[1][0][1]}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e7f6b3ebc68b> in <module>
#      11                               bootPlot_kw={'ci_size':6,'ci_width':2,'ref_width':2},
#      12                               swarmPlot_kw={'s':1,'m':'o', 'mfc':['none',1,1,'none'],
# ---> 13                                             'es_width':2})
#      14
#      15 ax, m, p = dpl.estimation_plot(input_, [KEYS[:2],KEYS[2:]], operation=np.mean, nsh=5000,ci=.95,
#
# ~/Python/difference_estimation_plot/difference_estimation_plot.py in estimation_plot(input_, indeces, vertical, EXC, trend, spread, paired, operation, SWARM, nsh, ci, nbins, BCA, SMOOTH, swarmPlot_kw, bootPlot_kw, trendPlot_kw, lbl_rot, color_palette, FontScale, axs, figsize, stat)
#     623                                           paired=paired, operation=operation, SMOOTH=SMOOTH,
#     624                                           vertical=vertical, BCA=BCA, nsh=nsh, lbl_rot=lbl_rot,
# --> 625                                           bootPlot_kw=bootPlot_kw, color_palette=color_palette)
#     626
#     627     # set common x axis limits
#
# ~/Python/difference_estimation_plot/difference_estimation_plot.py in bootstrap_plot(df, indeces, ax, operation, nsh, vertical, paired, BCA, nbins, ci, spread, SMOOTH, bootPlot_kw, color_palette, lbl_rot)
#     307     # SEt global params and initialise variables
#     308     if len(ci)>1:  alphas = np.array([ci[0], ci[1]])  # conf interval
# --> 309     alphas = np.array([(1 - ci) / 2., 1 - (1 - ci) / 2.])  # conf interval
#     310     x_offset = 0;  # x-axis offset for multiple controls
#     311     x_ind = 1  # index for colors etc
#
# TypeError: unsupported operand type(s) for -: 'int' and 'list'

# %% [markdown]
# #### p-value
# ```p``` is a list of lists with the first level indicating the group comparison, the second indicates the sample and the third has both the standard p-values and the one estimated with BCA

# %%
## Paired example:
input_ = {'sample 1': np.random.rand(10) + 1, 'sample 2': np.random.rand(10) + 1.2,
     'sample 3': np.random.rand(10) + .9}

ax,m,p = dpl.estimation_plot(input_, trend=1, nsh=5000, SMOOTH=[1,3], paired=True)
print(f'The standard bootstrap estimation p-values are: {p[0][0][0]} and {p[0][1][0]}')
print(f'The bca bootstrap estimation p-values are: {p[0][0][1]} and {p[0][1][1]}')
# Out:
# The standard bootstrap estimation p-values are: 0.00019999999999997797 and 0.0006000000000000449
# The bca bootstrap estimation p-values are: 0.00019999999999997797 and 0.0006000000000000449

# %%
## Paired example:
input_ = {'sample 1': np.random.rand(10) + 1, 'sample 2': np.random.rand(10) + 1.2}

fig, m, p = dpl.estimation_plot(input_, trend=1, nsh=5000, SMOOTH=[1,3], paired=True)
